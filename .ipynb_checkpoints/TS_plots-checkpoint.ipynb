# %% [markdown]
# # Outliers

# %%
# load required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('./Data/training2018.csv', parse_dates=True, header=0, index_col=0)
df2 = pd.read_csv('./Data/testing2018.csv', parse_dates=True, header=0, index_col=0)

# %%
frames = [df1, df2]

df = pd.concat(frames)

# %%
# create Series object
Tp = df['Tp']
Cl = df['Cl']
pH = df['pH']
Redox = df['Redox']
Leit = df['Leit']
Trueb= df['Trueb']
Cl2 = df['Cl_2']
Fm = df['Fm']
Fm_2 = df['Fm_2']

# %%
plt.figure(figsize=(15,3))
Tp.plot()
plt.show()

# %%
out1 = df['2016-09-07 07:23:00'  : '2016-09-07 10:40:00']
tout1= out1['Tp']
tout1.plot()
plt.show()

# %%
out1[df['EVENT'] == True].count()
# Out:
# /home/syka/anaconda2/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Tp       198
# Cl       198
# pH       198
# Redox    198
# Leit     198
# Trueb    198
# Cl_2     198
# Fm       198
# Fm_2     198
# EVENT    198
# dtype: int64

# %%
tout1.min()
# Out:
# 7.7

# %%
pho1= out1['pH']
pho1.plot()
plt.show()

# %%
pho1= out1['Trueb']
pho1.plot()
plt.show()

# %%
#df['label'] = np.where(df['EVENT'] == True)


# plot
# =============================
df = df.dropna(axis=0, how='any')

fig, ax = plt.subplots()

def plot_func(group):
    global ax
    color = 'r' if (group['label'] < 0).all() else 'g'
    lw = 2.0
    ax.plot(group.index, group.px_last, c=color, linewidth=lw)

df.groupby((df['label'].shift() * df['label'] < 0).cumsum()).apply(plot_func)

# add ma lines
ax.plot(df.index, df['50dma'], 'k--', label='MA-50')
ax.plot(df.index, df['200dma'], 'b--', label='MA-200')
ax.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-f55a171fb785> in <module>()
# ----> 1 df['label'] = np.where(df['EVENT'] == True)
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
# ...
